# %%
import pandas as pd

# %%
jee1 = pd.read_csv('../Data/JEE_Dropout_Cleaned.csv', delimiter=',')
jee2 = pd.read_csv('../Data/Feature_Engineered.csv', delimiter=',')

# %%
jee2.head()
# Out:
#    peer_focused_mh  PSxIA  daily_study_hours  location_type  \
# 0                0   0.00                5.4              2
# 1                1   1.65                5.5              2
# 2                3   0.00                7.0              1
# 3                3   2.49                2.1              1
# 4                4   9.16                6.3              1
#
#    Income vs Admission  family_income  parental_support  dropout
# 0                    0              0              1.62        1
# 1                    1              1              1.65        0
# 2                    0              0              2.70        1
# 3                    3              0              0.83        0
# 4                    4              1              2.29        0

# %%
jee_final = pd.concat([jee1, jee2[["Income vs Admission", "PSxIA", "peer_focused_mh","parental_support"]]], axis=1)
jee_final.head()
# Out:
#    jee_main_score  jee_advanced_score  mock_test_score_avg  school_board  \
# 0           78.95               59.22                59.86             1
# 1           70.06               58.75                64.33             0
# 2           81.07               37.27                60.83             2
# 3           93.32               60.72                69.33             2
# 4           68.72               77.73                82.37             1
#
#    class_12_percent  attempt_count  coaching_institute  daily_study_hours  \
# 0             70.09              1                   0                5.4
# 1             78.00              1                   0                5.5
# 2             64.36              1                   0                7.0
# 3             73.21              1                   0                2.1
# 4             89.02              1                   0                6.3
#
#    family_income  parent_education  location_type  peer_pressure_level  \
# ...

# %%
jee_final.to_csv('../Data/JEE_Dropout_Final.csv', index=False)
